# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
# Employee Technology Training Data - Version 01

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
# print(wb.sheet_names())
ws = wb.sheet_by_index(0)
# print (ws.cell_value(0, 0))
for i in range(0, ws.nrows):
    for j in range(0, ws.ncols):
        if ws.cell_value(i, j) == '':
            print ("NO VALID DATA")
        else:
            print (ws.cell_value(i, j))
    print ("\n")
# Out:
# Employee Id
# Name
# Angular-6
# Angular-7
# Angular-8
# Jquery
# Typescript
# NodeJS
# ReactJS
#
#
# 143184
# Kamelia Sinha
# NO VALID DATA
# NO VALID DATA
# July
# NO VALID DATA
# NO VALID DATA
# November
# October
#
#
# 46013981
# Raj kumar
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# August
# July
#
#
# 46016940
# M venu
# July
# July
# August
# July
# July
# August
# August
#
#
# 143700
# pratap pokala
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# December
# December
# November
#
#
# 168943
# Korrapati Pavitra Kumari
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# NO VALID DATA
# September
# July
#
#
# 165439
# Abhinava Y R
# August
# August
# September
# NO VALID DATA
# September
# October
# October
#
#
# 149286
# Sridharan
# July
# August
# August
# July
# July
# September
# September
#
#
# 147673
# RAJESH PRABHU MANGALORE
# December
# NO VALID DATA
# July
# NO VALID DATA
# July
# NO VALID DATA
# July
# ...

# %%
# Employee Technology Training Data - Version 01 - Iteration 01

# This code will capture data and place it in a list.
# Observation: 
# Change in indentation of 'myList2.append(myList1)' and 'myList1 = []' will allow data to be stored differently.
# An indentation with 4 spaces (one Tab length) will help us have one field entry as a list to parent list
# An indentation with 8 spaces (two tab length) will make data from individual cells as list items to the parent list. 
# Execute the below code to understand it better. 
import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("NO VALID DATA")
        else:
            myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    # print ("\n")
print (myList2)
# Out:
# [['Employee Id'], ['Name'], ['Angular-6'], ['Angular-7'], ['Angular-8 '], ['Jquery'], ['Typescript'], ['NodeJS'], ['ReactJS'], ['143184'], ['Kamelia Sinha'], ['NO VALID DATA'], ['NO VALID DATA'], ['July'], ['NO VALID DATA'], ['NO VALID DATA'], ['November'], ['October'], ['46013981'], ['Raj kumar'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['August'], ['July'], ['46016940'], ['M venu'], ['July'], ['July'], ['August'], ['July'], ['July'], ['August'], ['August'], ['143700'], ['pratap pokala'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['December'], ['December'], ['November'], ['168943'], ['Korrapati Pavitra Kumari'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['NO VALID DATA'], ['September'], ['July'], ['165439'], ['Abhinava Y R'], ['August'], ['August'], ['September'], ['NO VALID DATA'], ['September'], ['October'], ['October'], ['149286'], ['Sridharan'], ['July'], ['
# ...

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("NO VALID DATA")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
    # print ("\n")
# print (myList2)
mySet = set()
for i in range (0, ws.nrows):
    # print (myList2[i][0], "\t", myList2[i][2], "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
    # print (len(str(int(myList2[i][0]))))
    # mySet.add(len(str(int(myList2[i][0]))))
    if isinstance(myList2[i][0], str) == False:
        print (i, "Found One Black Sheep")
    # else:
    #     print (i, "False")
# print (mySet)
# Out:
# 72 Found One Black Sheep

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("NO VALID DATA")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
    # print ("\n")
# print (myList2)
mySet = set()

# Code to verify if Employee ID is of data type string. 
"""
for i in range (0, ws.nrows):
    if isinstance(myList2[i][0], str) == False:
        print (i, "Found One Black Sheep in Employee ID")
"""
# Code to verify if Employee ID is of data type int. 
try: 
    for i in range (0, ws.nrows):
        if isinstance(int(myList2[i][0]), int) == False:
            print (i, "Error: Inconsistent Data")
except ValueError:
    print ("String Cannot be converted to Integer")
# print (mySet)
# Out:
# String Cannot be converted to Integer

# %%
empIDlst = []
for i in range (0, ws.nrows):
    try: 
        if isinstance(int(myList2[i][0]), int) == True:
            print (i, "Data Okay")
            empIDlst.append(myList2[i][0])
    except ValueError:
        print (i, "Inconsistent Data")
        
print (empIDlst)
# Out:
# 0 Inconsistent Data
# 1 Data Okay
# 2 Data Okay
# 3 Data Okay
# 4 Data Okay
# 5 Data Okay
# 6 Data Okay
# 7 Data Okay
# 8 Data Okay
# 9 Data Okay
# 10 Data Okay
# 11 Data Okay
# 12 Data Okay
# 13 Data Okay
# 14 Data Okay
# 15 Data Okay
# 16 Data Okay
# 17 Data Okay
# 18 Data Okay
# 19 Data Okay
# 20 Data Okay
# 21 Data Okay
# 22 Data Okay
# 23 Data Okay
# 24 Data Okay
# 25 Data Okay
# 26 Data Okay
# 27 Data Okay
# 28 Data Okay
# 29 Data Okay
# 30 Data Okay
# 31 Data Okay
# 32 Data Okay
# 33 Data Okay
# 34 Data Okay
# 35 Data Okay
# 36 Data Okay
# 37 Data Okay
# 38 Data Okay
# 39 Data Okay
# 40 Data Okay
# 41 Data Okay
# 42 Data Okay
# 43 Data Okay
# 44 Data Okay
# 45 Data Okay
# 46 Data Okay
# 47 Data Okay
# 48 Data Okay
# 49 Data Okay
# 50 Inconsistent Data
# 51 Data Okay
# 52 Data Okay
# 53 Data Okay
# 54 Data Okay
# 55 Data Okay
# 56 Data Okay
# 57 Data Okay
# 58 Data Okay
# 59 Data Okay
# 60 Data Okay
# 61 Data Okay
# 62 Data Okay
# 63 Data Okay
# 64 Data Okay
# 65 Data Okay
# ...

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("INVALID")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
    # print ("\n")
# print (myList2)
mySet = set()
for i in range (0, ws.nrows):
    if len(str(myList2[i][0])) > 4 and len(str(myList2[i][0])) < 8:
        print (myList2[i][0], "\t\t", myList2[i][2], "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
        # if len(str(myList2[i][2])) >= 4 and len(str(myList2[i][2])) < 8:
            # print (myList2[i][0], "\t\t", myList2[i][2], "\t", myList2[i][3], "\t\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
    else:
        print (myList2[i][0], "\t", myList2[i][2], "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
        
    # mySet.add(len(str(int(myList2[i][0]))))
    # if isinstance(myList2[i][0], str) == False:
    #    print (i, "Found One Black Sheep")
    # else:
    #     print (i, "False")
# print (mySet)
# Out:
# Employee Id 	 Angular-6 	 Angular-7 	 Angular-8  	 Angular-8  	 Typescript
# 143184 		 INVALID 	 INVALID 	 July 	 July 	 INVALID
# 46013981 	 INVALID 	 INVALID 	 INVALID 	 INVALID 	 INVALID
# 46016940 	 July 	 July 	 August 	 August 	 July
# 143700 		 INVALID 	 INVALID 	 INVALID 	 INVALID 	 December
# 168943 		 INVALID 	 INVALID 	 INVALID 	 INVALID 	 INVALID
# 165439 		 August 	 August 	 September 	 September 	 September
# 149286 		 July 	 August 	 August 	 August 	 July
# 147673 		 December 	 INVALID 	 July 	 July 	 July
# 46002548 	 August 	 INVALID 	 September 	 September 	 INVALID
# 46001193 	 July 	 INVALID 	 August 	 August 	 July
# 46001193 	 INVALID 	 INVALID 	 August 	 August 	 July
# 46013986 	 INVALID 	 INVALID 	 INVALID 	 INVALID 	 September
# 144980 		 July 	 August 	 August 	 August 	 September
# 156950 		 INVALID 	 INVALID 	 October 	 October 	 September
# 163243 		 November 	 October 	 September 	 September 	 INVALID
# ...

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("INVALID")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
    # print ("\n")
# print (myList2)
mySet = set()
for i in range (0, ws.nrows):
    print (myList2[i][0], "\t", myList2[i][2], "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-70a2c3556b2e> in <module>
#      19 mySet = set()
#      20 for i in range (0, ws.nrows):
# ---> 21     print (pd.rjust(myList2[i][0]), "\t", rjust(myList2[i][2]), "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'rjust'

# %%
## Add the space at Start of the string in Python
 
string2="Test String leading space to be added"
string_length=len(string2)+10    # will be adding 10 extra spaces
string_revised=string2.rjust(string_length)
print (string_revised)
# Out:
#           Test String leading space to be added

# %%
myStrList = ['a', 'ab', 'abc', 'abcd', 'abcde']
print (type(myStrList))
strLenVal = []
for eachElement in myStrList:
    strLenVal.append(len(eachElement))
tempStrLen = 0

if len(myStrList[0]) < max(strLenVal):
    # tempStrLen = len(myStrList[0]) + (max(strLenVal) - len(myStrList[0]))
    tempStrLen = max(strLenVal) - len(myStrList[0])
# print (len(myStrList[0]), tempStrLen)
print ((myStrList[0]).rjust(tempStrLen))
# Out:
# <class 'list'>
#    a

# %%
myStrList = ['a', 'ab', 'abc', 'abcd', 'abcde']                # Test Data Set
strLenVal = []                                                 # Temporary list to store length of all elements in data set
for eachElement in myStrList:
    strLenVal.append(len(eachElement))
tempStrLen = 0

# Right Justification
for i in range(0, len(myStrList)):
    if len(myStrList[i]) < max(strLenVal):
        tempStrLen = max(strLenVal) - len(myStrList[0])
    print ((myStrList[i]).rjust(tempStrLen))
# Out:
#    a
#   ab
#  abc
# abcd
# abcde

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
print ("Employees Training Data - Location:", wb.sheet_names()) # Store in a list and print it with help of index number.

# List1 appends replaces empty spaces with 'INVALID' and List2 is nested list of each record with all colums
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("INVALID")
        else:
            myList1.append(str(ws.cell_value(j, i)))
    myList2.append(myList1)
    myList1 = []

# List3 is a collection of all values in nested lists of List2 
myList3 = []
for i in range (0, ws.nrows):
    for j in range (0, ws.ncols):
        myList3.append(myList2[i][j])

# List4 is collection of string lengths of all values of List3
myList4 = []
for i in range (0, len(myList3)):
    myList4.append(len(str(myList3[i])))

# Following code is right justifying all the values in List4
for i in range (0, ws.nrows):
    for j in range (0, ws.ncols):
        if len(myList2[i][j]) < max(myList4):
            tempStrLen = max(myList4) - len(myStrList[0])
            # print (tempStrLen)
        print (myList2[i][j].rjust(tempStrLen))
    print ("\n")
# Out:
# Employees Training Data - Location: ['Bangalore', 'Noida&Others', 'Chennai', 'Pune', 'Mumbai']
#                  Employee Id
#                         Name
#                    Angular-6
#                    Angular-7
#                   Angular-8
#                       Jquery
#                   Typescript
#                       NodeJS
#                      ReactJS
#
#
#                       143184
#                Kamelia Sinha
#                      INVALID
#                      INVALID
#                         July
#                      INVALID
#                      INVALID
#                     November
#                      October
#
#
#                     46013981
#                    Raj kumar
#                      INVALID
#                      INVALID
#                      INVALID
#                      INVALID
#                      INVALID
#                       August
#                         July
#
#
#                     46016940
# ...

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("INVALID")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
mySet = set()
for i in range (0, ws.nrows):
    if len(str(myList2[i][0])) > 4 and len(str(myList2[i][0])) < 8:
        print (myList2[i][0], "\t\t", myList2[i][2], "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
    else:
        print (myList2[i][0], "\t", myList2[i][2], "\t", myList2[i][3], "\t", myList2[i][4], "\t", myList2[i][4], "\t", myList2[i][6])
# Out:
# Employee Id 	 Angular-6 	 Angular-7 	 Angular-8  	 Angular-8  	 Typescript
# 143184 		 INVALID 	 INVALID 	 July 	 July 	 INVALID
# 46013981 	 INVALID 	 INVALID 	 INVALID 	 INVALID 	 INVALID
# 46016940 	 July 	 July 	 August 	 August 	 July
# 143700 		 INVALID 	 INVALID 	 INVALID 	 INVALID 	 December
# 168943 		 INVALID 	 INVALID 	 INVALID 	 INVALID 	 INVALID
# 165439 		 August 	 August 	 September 	 September 	 September
# 149286 		 July 	 August 	 August 	 August 	 July
# 147673 		 December 	 INVALID 	 July 	 July 	 July
# 46002548 	 August 	 INVALID 	 September 	 September 	 INVALID
# 46001193 	 July 	 INVALID 	 August 	 August 	 July
# 46001193 	 INVALID 	 INVALID 	 August 	 August 	 July
# 46013986 	 INVALID 	 INVALID 	 INVALID 	 INVALID 	 September
# 144980 		 July 	 August 	 August 	 August 	 September
# 156950 		 INVALID 	 INVALID 	 October 	 October 	 September
# 163243 		 November 	 October 	 September 	 September 	 INVALID
# ...
