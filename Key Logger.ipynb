# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
import sys
# !{sys.executable} -m pip list | findstr pynput
# Out:
# pynput                             1.6.8

# %%
import sys
# !{sys.executable} -m pip install pynput
# Out:
# Collecting pynput
#   Downloading pynput-1.6.8-py2.py3-none-any.whl (91 kB)
# Requirement already satisfied: six in d:\programdata\anaconda3\lib\site-packages (from pynput) (1.14.0)
# Installing collected packages: pynput
# Successfully installed pynput-1.6.8

# %%
from pynput.keyboard import Key, Listener

currently_pressed_key = None

def on_press(key):
    global currently_pressed_key
    if key == currently_pressed_key:
        print('{0} repeated'.format(key))
    else:
        print('{0} pressed'.format(key))
        currently_pressed_key = key

def on_release(key):
    global currently_pressed_key
    print('{0} release'.format(key))
    currently_pressed_key = None
    if key == Key.esc:
        # Stop listener
        return False

# Collect events until released
with Listener(
        on_press=on_press,
        on_release=on_release) as listener:
    listener.join()
# Out:
# Key.ctrl_l release
# 'a' pressed
# 'a' release
# 'v' pressed
# 'v' release
# 'c' pressed
# 'c' release
# Key.backspace pressed
# Key.backspace release
# Key.enter pressed
# Key.enter release
# Key.shift pressed
# 'T' pressed
# Key.shift release
# 't' release
# 'h' pressed
# 'i' pressed
# 'h' release
# 's' pressed
# 'i' release
# 's' release
# Key.space pressed
# 'i' pressed
# Key.space release
# 's' pressed
# 'i' release
# 's' release
# Key.space pressed
# 's' pressed
# Key.space release
# 's' release
# Key.space pressed
# Key.space release
# Key.backspace pressed
# Key.backspace release
# Key.backspace pressed
# Key.backspace release
# 'a' pressed
# 'a' release
# Key.space pressed
# Key.space release
# 'p' pressed
# 'a' pressed
# 'p' release
# 'a' release
# 's' pressed
# 's' release
# 's' pressed
# 's' release
# 'w' pressed
# 'w' release
# 'o' pressed
# 'r' pressed
# 'o' release
# 'r' release
# 'd' pressed
# 'd' release
# Key.shift pressed
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# Key.shift repeated
# 'K' pressed
# Key.shift release
# 'k' release
# 'e' pressed
# 'e' release
# 'y' pressed
# 'y' release
# Key.space pressed
# Key.shift pressed
# Key.space release
# 'L' pressed
# 'L' release
# Key.shift release
# 'o' pressed
# 'o' release
# 'g' pressed
# 'g' release
# 'g' pressed
# 'g' release
# 'e' pressed
# 'e' release
# 'r' pressed
# 'r' release
# Key.enter pressed
# Key.enter release
# Key.enter pressed
# Key.enter release
# 'o' pressed
# 'o' release
# 'o' pressed
# 'o' release
# 'p' pressed
# 'p' release
# 's' pressed
# 's' release
# Key.space pressed
# Key.space release
# 'i' pressed
# 'i' release
# 't' pressed
# 't' release
# Key.space pressed
# Key.space release
# 'i' pressed
# 'i' release
# 's' pressed
# Key.space pressed
# 's' release
# Key.space release
# 'l' pressed
# 'l' release
# 'o' pressed
# 'o' release
# 'g' pressed
# 'g' release
# 'g' pressed
# 'g' release
# 'i' pressed
# 'n' pressed
# 'i' release
# 'n' release
# 'g' pressed
# 'g' release
# Key.space pressed
# Key.space release
# 'i' pressed
# 'i' release
# 'n' pressed
# 'n' release
# Key.backspace pressed
# Key.backspace release
# 't' pressed
# 't' release
# Key.space pressed
# Key.space release
# 'i' pressed
# 'n' pressed
# 'i' release
# Key.space pressed
# 'n' release
# Key.space release
# 'c' pressed
# 'l' pressed
# 'c' release
# 'l' release
# 'e' pressed
# 'a' pressed
# 'e' release
# 'r' pressed
# 'a' release
# 'r' release
# Key.space pressed
# Key.space release
# 't' pressed
# 'e' pressed
# 't' release
# 'e' release
# 'x' pressed
# 'x' release
# 't' pressed
# 't' release
# Key.shift pressed
# ':' pressed
# ':' release
# Key.shift release
# Key.shift pressed
# Key.home pressed
# Key.home release
# Key.up pressed
# Key.up release
# Key.shift release
# Key.backspace pressed
# Key.backspace release
# Key.backspace pressed
# Key.backspace release
# Key.backspace pressed
# Key.backspace release
# Key.ctrl_l pressed
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l release
# Key.ctrl_l pressed
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
# Key.ctrl_l repeated
