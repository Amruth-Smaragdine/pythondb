# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
# Employee Technology Training Data - Version 01 - Iteration 02

import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)
# print ("Employees Training Data - Location:", wb.sheet_names()) # Store in a list and print it with help of index number.

# List1 appends replaces empty spaces with 'INVALID' and List2 is nested list of each record with all colums
myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("INVALID")
        else:
            myList1.append(str(ws.cell_value(j, i)))
    myList2.append(myList1)
    myList1 = []

# List3 is a collection of all values in nested lists of List2 
myList3 = []
for i in range (0, ws.nrows):
    for j in range (0, ws.ncols):
        myList3.append(myList2[i][j])

# List4 is collection of string lengths of all values of List3
myList4 = []
for i in range (0, len(myList3)):
    myList4.append(len(str(myList3[i])))

# Following code is right justifying all the values in List4
def myGenFunc(a):
    """
    Function will return the character space to help us with left (or) right Justification
    """
    myGenSet = set()
    count = 0
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            myGenSet.add (len(myList2[i][a]))
    return (max(myGenSet))
    # return max(myGenSet)
# print (max(mySetNJS))
myGenFunc(0)
for i in range (0, ws.nrows):
    print (myList2[i][0].rjust(myGenFunc(0), ' '), myList2[i][1].ljust(myGenFunc(1), ' '), \
           myList2[i][2].ljust(myGenFunc(2), ' '), myList2[i][3].ljust(myGenFunc(3), ' '), \
           myList2[i][4].ljust(myGenFunc(4), ' '), myList2[i][5].ljust(myGenFunc(5), ' '), \
           myList2[i][6].ljust(myGenFunc(6), ' '), myList2[i][7].ljust(myGenFunc(7), ' '), \
           myList2[i][8].ljust(myGenFunc(8), ' '))
# Out:
# Employees Training Data - Location: ['Bangalore', 'Noida&Others', 'Chennai', 'Pune', 'Mumbai']
# Employee Id Name                          Angular-6 Angular-7 Angular-8  Jquery    Typescript NodeJS    ReactJS
#      143184 Kamelia Sinha                 INVALID   INVALID   July       INVALID   INVALID    November  October
#    46013981 Raj kumar                     INVALID   INVALID   INVALID    INVALID   INVALID    August    July
#    46016940 M venu                        July      July      August     July      July       August    August
#      143700 pratap pokala                 INVALID   INVALID   INVALID    INVALID   December   December  November
#      168943 Korrapati Pavitra Kumari      INVALID   INVALID   INVALID    INVALID   INVALID    September July
#      165439 Abhinava Y R                  August    August    September  INVALID   September  October   October
#      149286 Sridharan                     July      August    August     July      July       September September
#      147673 RAJESH PRABHU MANGALORE       December  INVALID   July       INVALID   July       INVALID   July
#    46002548 Neeraj Kumar Prajapati        August    INVALID   September  INVALID   INVALID    July      July
#    46001193 Akshdeep kaur sidhu           July      INVALID   August     INVALID   July       INVALID   July
#    46001193 Akshdeep kaur sidhu           INVALID   INVALID   August     September July       October   July
#    46013986 sekhar kishorekumar           INVALID   INVALID   INVALID    INVALID   September  August    July
#      144980 Y Sasivardhan Reddy           July      August    August     July      September  INVALID   September
#      156950 Varun R                       INVALID   INVALID   October    INVALID   September  July      August
#      163243 Mudhireddy Surekha            November  October   September  INVALID   INVALID    August    July
#      151097 Shreemudra Satapathy          INVALID   INVALID   INVALID    September September  July      August
#      115949 vishal rai                    September September August     INVALID   July       August    July
#      119618 Senthil Shanmugam             July      October   December   INVALID   August     September November
#      168944 Lohithashree P S              INVALID   INVALID   INVALID    INVALID   INVALID    INVALID   July
#    46001093 vishal bansal                 December  November  October    August    September  August    July
#       68149 Venkataramanarao              September October   November   July      August     December  August
#      168965 Mounika Narla                 July      August    August     August    July       September August
#       75029 Aditi Sharma                  July      July      August     August    September  October   November
#      159884 Valmiki Sai Puneeth           August    September October    July      July       September August
#      117612 Ritu Agrawal                  September October   November   December  August     July      August
#      168541 Lavanya KS                    July      July      July       August    July       September INVALID
#      116244 Adarsh Valamary               INVALID   INVALID   August     INVALID   July       INVALID   September
#    46004786 Sathyanarayana L J            December  October   INVALID    August    July       August    July
#      122597 Prajwala tarugu               July      August    October    INVALID   September  December  August
#      115569 Syed Roshan                   INVALID   INVALID   INVALID    July      INVALID    July      July
#    46001171 Argha Boksi                   INVALID   INVALID   INVALID    INVALID   INVALID    July      August
#      167469 Swathi Umesh Naik             October   October   October    November  December   August    September
#      162835 Karthik Devaraj               July      August    September  INVALID   November   December  October
#    46018744 Garlapati Mohan               July      July      July       August    July       August    September
#    46001213 Pushan Banerjee               November  November  July       November  August     August    August
#    46010556 Sai Vamshi Krishna Nama       INVALID   INVALID   INVALID    INVALID   August     July      INVALID
#    46001212 Kasu Narsimharaj              December  August    September  July      October    August    November
#    46001192 Shirin Shaw                   INVALID   INVALID   INVALID    INVALID   INVALID    INVALID   July
#      143655 Venkata kumar                 July      August    September  October   August     November  December
#      176838 Vinod K                       INVALID   INVALID   August     INVALID   INVALID    INVALID   October
#    46020214 Gowsick Ragupathi             INVALID   INVALID   INVALID    INVALID   August     September July
#      191231 Rineesh Babu                  INVALID   INVALID   INVALID    INVALID   INVALID    July      July
#      118772 Samyuktha Tamatam             September October   November   December  August     July      December
#      152095 Soniya Asati                  July      July      August     October   July       August    August
#      168946 Syed Irfan Rizvi              September October   December   July      September  August    July
#      144129 Aravind Keelapatta            July      INVALID   July       August    July       July      August
#    46018505 Dindukurthi Sai Jayanth Kumar September July      July       July      September  October   November
#      156808 Vamsi Krishna                 INVALID   INVALID   August     INVALID   September  INVALID   October
#      174091 Monisha Shanil                July      August    September  December  July       November  October
#     avsheth Avni                          July      August    September  INVALID   July       September October
#    46022732 Gururaja CS                   September September September  September August     August    August
#      147673 Rajesh Prabhu Mangalore       INVALID   INVALID   INVALID    INVALID   July       July      July
#      176111 Lal Sahab                     INVALID   INVALID   August     October   August     September September
#      169341 Sandhya Prasanna              INVALID   INVALID   November   September October    July      August
#      140461 Mukesh kumar singh            INVALID   INVALID   INVALID    INVALID   INVALID    July      INVALID
#      143184 Kamelia Sinha                 INVALID   INVALID   July       October   August     INVALID   November
#      175212 Abhishek Kumar                July      August    September  INVALID   October    November  December
#       23028 srinivasa rao dasari          August    September October    INVALID   August     August    September
#      168919 kunapareddy praneeth          November  October   July       INVALID   December   September August
#      120520 Lakshmi kumari Ekula          August    September October    INVALID   July       November  July
#    46018816 Yogendra cp                   August    July      July       September September  October   October
#    46012480 Jayanthrowth C V              INVALID   December  August     November  October    July      September
#      159885 Abhishek Shukla               August    September October    July      July       November  December
#    46004137 Rajesh Kumar Pradhan          INVALID   INVALID   August     INVALID   INVALID    July      INVALID
#      168919 kunapareddy praneeth          INVALID   INVALID   July       November  October    September August
#      094381 Sowmya                        August    August    August     July      July       September September
#      124701 Chandradhar S Gujjalar        August    September October    November  July       December  December
#      126631 Seema                         July      July      July       July      July       July      July
#    46002410 Aneela Ammu Thomas            July      INVALID   INVALID    July      July       INVALID   July
#      173791 SIBBIR AHMED                  November  November  October    December  July       August    September
#      143168 Geet Sethi                    July      INVALID   September  INVALID   November   August    December
#    115175.0 Yatheesh Valakadama           INVALID   INVALID   October    INVALID   September  November  December

# %%
# Employee Technology Training Data - Version 01 - Iteration 02
import xlrd
wb = xlrd.open_workbook("02-EmployeeTrainingData-Complete.xlsx")
ws = wb.sheet_by_index(0)

myList1 = []
myList2 = []
for j in range(0, ws.nrows):
    for i in range(0, ws.ncols):
        if ws.cell_value(j, i) == '':
            myList1.append("INVALID")
        else:
            myList1.append(str(ws.cell_value(j, i)))
    myList2.append(myList1)
    myList1 = []

myList3 = []
for i in range (0, ws.nrows):
    for j in range (0, ws.ncols):
        myList3.append(myList2[i][j])

myList4 = []
for i in range (0, len(myList3)):
    myList4.append(len(str(myList3[i])))

def myGenFunc(a):
    """
    Function will return the character space to help us with left (or) right Justification
    """
    myGenSet = set()
    count = 0
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            myGenSet.add (len(myList2[i][a]))
    return (max(myGenSet))
myGenFunc(0)
for i in range (0, ws.nrows):
    print (myList2[i][0].rjust(myGenFunc(0), ' '), myList2[i][1].ljust(myGenFunc(1), ' '), \
           myList2[i][2].ljust(myGenFunc(2), ' '), myList2[i][3].ljust(myGenFunc(3), ' '), \
           myList2[i][4].ljust(myGenFunc(4), ' '), myList2[i][5].ljust(myGenFunc(5), ' '), \
           myList2[i][6].ljust(myGenFunc(6), ' '), myList2[i][7].ljust(myGenFunc(7), ' '), \
           myList2[i][8].ljust(myGenFunc(8), ' '))
# Out:
# Employee Id Name                          Angular-6 Angular-7 Angular-8  Jquery    Typescript NodeJS    ReactJS
#      143184 Kamelia Sinha                 INVALID   INVALID   July       INVALID   INVALID    November  October
#    46013981 Raj kumar                     INVALID   INVALID   INVALID    INVALID   INVALID    August    July
#    46016940 M venu                        July      July      August     July      July       August    August
#      143700 pratap pokala                 INVALID   INVALID   INVALID    INVALID   December   December  November
#      168943 Korrapati Pavitra Kumari      INVALID   INVALID   INVALID    INVALID   INVALID    September July
#      165439 Abhinava Y R                  August    August    September  INVALID   September  October   October
#      149286 Sridharan                     July      August    August     July      July       September September
#      147673 RAJESH PRABHU MANGALORE       December  INVALID   July       INVALID   July       INVALID   July
#    46002548 Neeraj Kumar Prajapati        August    INVALID   September  INVALID   INVALID    July      July
#    46001193 Akshdeep kaur sidhu           July      INVALID   August     INVALID   July       INVALID   July
#    46001193 Akshdeep kaur sidhu           INVALID   INVALID   August     September July       October   July
#    46013986 sekhar kishorekumar           INVALID   INVALID   INVALID    INVALID   September  August    July
#      144980 Y Sasivardhan Reddy           July      August    August     July      September  INVALID   September
#      156950 Varun R                       INVALID   INVALID   October    INVALID   September  July      August
#      163243 Mudhireddy Surekha            November  October   September  INVALID   INVALID    August    July
#      151097 Shreemudra Satapathy          INVALID   INVALID   INVALID    September September  July      August
#      115949 vishal rai                    September September August     INVALID   July       August    July
#      119618 Senthil Shanmugam             July      October   December   INVALID   August     September November
#      168944 Lohithashree P S              INVALID   INVALID   INVALID    INVALID   INVALID    INVALID   July
#    46001093 vishal bansal                 December  November  October    August    September  August    July
#       68149 Venkataramanarao              September October   November   July      August     December  August
#      168965 Mounika Narla                 July      August    August     August    July       September August
#       75029 Aditi Sharma                  July      July      August     August    September  October   November
#      159884 Valmiki Sai Puneeth           August    September October    July      July       September August
#      117612 Ritu Agrawal                  September October   November   December  August     July      August
#      168541 Lavanya KS                    July      July      July       August    July       September INVALID
#      116244 Adarsh Valamary               INVALID   INVALID   August     INVALID   July       INVALID   September
#    46004786 Sathyanarayana L J            December  October   INVALID    August    July       August    July
#      122597 Prajwala tarugu               July      August    October    INVALID   September  December  August
#      115569 Syed Roshan                   INVALID   INVALID   INVALID    July      INVALID    July      July
#    46001171 Argha Boksi                   INVALID   INVALID   INVALID    INVALID   INVALID    July      August
#      167469 Swathi Umesh Naik             October   October   October    November  December   August    September
#      162835 Karthik Devaraj               July      August    September  INVALID   November   December  October
#    46018744 Garlapati Mohan               July      July      July       August    July       August    September
#    46001213 Pushan Banerjee               November  November  July       November  August     August    August
#    46010556 Sai Vamshi Krishna Nama       INVALID   INVALID   INVALID    INVALID   August     July      INVALID
#    46001212 Kasu Narsimharaj              December  August    September  July      October    August    November
#    46001192 Shirin Shaw                   INVALID   INVALID   INVALID    INVALID   INVALID    INVALID   July
#      143655 Venkata kumar                 July      August    September  October   August     November  December
#      176838 Vinod K                       INVALID   INVALID   August     INVALID   INVALID    INVALID   October
#    46020214 Gowsick Ragupathi             INVALID   INVALID   INVALID    INVALID   August     September July
#      191231 Rineesh Babu                  INVALID   INVALID   INVALID    INVALID   INVALID    July      July
#      118772 Samyuktha Tamatam             September October   November   December  August     July      December
#      152095 Soniya Asati                  July      July      August     October   July       August    August
#      168946 Syed Irfan Rizvi              September October   December   July      September  August    July
#      144129 Aravind Keelapatta            July      INVALID   July       August    July       July      August
#    46018505 Dindukurthi Sai Jayanth Kumar September July      July       July      September  October   November
#      156808 Vamsi Krishna                 INVALID   INVALID   August     INVALID   September  INVALID   October
#      174091 Monisha Shanil                July      August    September  December  July       November  October
#     avsheth Avni                          July      August    September  INVALID   July       September October
#    46022732 Gururaja CS                   September September September  September August     August    August
#      147673 Rajesh Prabhu Mangalore       INVALID   INVALID   INVALID    INVALID   July       July      July
#      176111 Lal Sahab                     INVALID   INVALID   August     October   August     September September
#      169341 Sandhya Prasanna              INVALID   INVALID   November   September October    July      August
#      140461 Mukesh kumar singh            INVALID   INVALID   INVALID    INVALID   INVALID    July      INVALID
#      143184 Kamelia Sinha                 INVALID   INVALID   July       October   August     INVALID   November
#      175212 Abhishek Kumar                July      August    September  INVALID   October    November  December
#       23028 srinivasa rao dasari          August    September October    INVALID   August     August    September
#      168919 kunapareddy praneeth          November  October   July       INVALID   December   September August
#      120520 Lakshmi kumari Ekula          August    September October    INVALID   July       November  July
#    46018816 Yogendra cp                   August    July      July       September September  October   October
#    46012480 Jayanthrowth C V              INVALID   December  August     November  October    July      September
#      159885 Abhishek Shukla               August    September October    July      July       November  December
#    46004137 Rajesh Kumar Pradhan          INVALID   INVALID   August     INVALID   INVALID    July      INVALID
#      168919 kunapareddy praneeth          INVALID   INVALID   July       November  October    September August
#      094381 Sowmya                        August    August    August     July      July       September September
#      124701 Chandradhar S Gujjalar        August    September October    November  July       December  December
#      126631 Seema                         July      July      July       July      July       July      July
#    46002410 Aneela Ammu Thomas            July      INVALID   INVALID    July      July       INVALID   July
#      173791 SIBBIR AHMED                  November  November  October    December  July       August    September
#      143168 Geet Sethi                    July      INVALID   September  INVALID   November   August    December
#    115175.0 Yatheesh Valakadama           INVALID   INVALID   October    INVALID   September  November  December

# %%
for i in range(0, ws.nrows):
    for j in range (0, ws.ncols):
        print (type(myList2[i][j]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
