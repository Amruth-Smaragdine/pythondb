# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
# Code to extract employee data from MS Excel sheet using XLRD package
# Code to understand and construct 'for' loop

import xlrd
wb = xlrd.open_workbook("01-EmployeeData.xlsx")
ws = wb.sheet_by_index(0)
# print (ws.cell_value(0, 0))
myList1 = []
myList2 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(0, i))
myList2.append(myList1)
# print (myList2)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(1, i))
myList2.append(myList1)
# print (myList2)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(2, i))
myList2.append(myList1)
print (myList2)
myList1 = []
# Out:
# [['SLNO', 'serial', 'Emp Name', 'Email ID', 'Final Grade', 'Location', 'Fresher', 'Hire Date', 'LWD', 'Practice', 'Service Line', 'Primary Skills', 'Secondary Skill', 'Supervisor Name', 'PID', 'Project Name', 'Project Manager', 'Account', 'Allocation Start Date', 'Allocation end date', 'Allocation Start Date2', 'Allocation end Date2', 'Start month', 'End month', 'Net working days', 'Copy of U', 'Vlook up formual', 'Consideration of start and end dates', 'Copy of X', 'Division', 'Consideration of Abscondee, Long Leave p/up', 'FTE', 'Resource Current Status ', 'Delivery BU', 'Delivery Region', 'Sector/Country', 'OU Code', 'SEZ/Non-SEZ', 'Emp Type', 'Captives/P&C', 'Generic Skill', 'Project Type', 'Resource Type', 'Hire month'], ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', '', 'No', '', 'CSS', ''], ['ID0002', 165439.0, 'Abhinava Abhinava', 'emp_name@mail.com2', 'B', 'Bangalore', 'No', 43404.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Prachi Vinay Kulkarni', 'PID0002', 'PN002', 'PM002', 'AC002', 43864.333333333336, 44008.708333333336, 43864.0, 44008.0, 43983.0, 44008.0, 20.0, 20.0, 20.0, 22.0, 22.0, 0.9090909090909091, 0.9090909090909091, 0.9090909090909091, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', '']]

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 01
# Code to understand and construct 'for' loop

import xlrd
wb = xlrd.open_workbook("01-EmployeeData.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []

# print (ws.nrows)
# print (ws.ncols)
for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(0, i))
myList2.append(myList1)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(1, i))
myList2.append(myList1)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(2, i))
myList2.append(myList1)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(3, i))
myList2.append(myList1)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(4, i))
myList2.append(myList1)
myList1 = []

for i in range (0, ws.ncols):
    myList1.append(ws.cell_value(5, i))
myList2.append(myList1)
myList1 = []

print (myList2)
# Out:
# 291
# 44
# [['SLNO', 'serial', 'Emp Name', 'Email ID', 'Final Grade', 'Location', 'Fresher', 'Hire Date', 'LWD', 'Practice', 'Service Line', 'Primary Skills', 'Secondary Skill', 'Supervisor Name', 'PID', 'Project Name', 'Project Manager', 'Account', 'Allocation Start Date', 'Allocation end date', 'Allocation Start Date2', 'Allocation end Date2', 'Start month', 'End month', 'Net working days', 'Copy of U', 'Vlook up formual', 'Consideration of start and end dates', 'Copy of X', 'Division', 'Consideration of Abscondee, Long Leave p/up', 'FTE', 'Resource Current Status ', 'Delivery BU', 'Delivery Region', 'Sector/Country', 'OU Code', 'SEZ/Non-SEZ', 'Emp Type', 'Captives/P&C', 'Generic Skill', 'Project Type', 'Resource Type', 'Hire month'], ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', '', 'No', '', 'CSS', ''], ['ID0002', 165439.0, 'Abhinava Abhinava', 'emp_name@mail.com2', 'B', 'Bangalore', 'No', 43404.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Prachi Vinay Kulkarni', 'PID0002', 'PN002', 'PM002', 'AC002', 43864.333333333336, 44008.708333333336, 43864.0, 44008.0, 43983.0, 44008.0, 20.0, 20.0, 20.0, 22.0, 22.0, 0.9090909090909091, 0.9090909090909091, 0.9090909090909091, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0003', 175212.0, 'abhishek kumar', 'emp_name@mail.com3', 'B', 'Bangalore', 'No', 43521.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0003', 'PN003', 'PM003', 'AC003', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.5789473684210527, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0004', 159885.0, 'Abhishek Shukla', 'emp_name@mail.com4', 'A', 'Bangalore', 'Yes', 43348.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Rajendran Manickam', 'PID0004', 'PN004', 'PM004', 'AC004', 43830.333333333336, 44196.708333333336, 43830.0, 44196.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Billable', 'DCX', 'INDIA', 'IN', 'IN52', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0005', 116244.0, 'Adarsh Valamary', 'emp_name@mail.com5', 'B', 'Bangalore', 'No', 42644.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Govind Murari', 'PID0005', 'PN005', 'PM005', 'AC005', 43864.333333333336, 44001.708333333336, 43864.0, 44001.0, 43983.0, 44001.0, 15.0, 15.0, 17.0, 22.0, 22.0, 0.6818181818181818, 0.6818181818181818, 0.6818181818181818, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'Non-SEZ', 'Standard', '', 'No', 'External', 'CSS', '']]

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 02
# With the knowhow from above manual process, formulated for loop which is working well as expected

import xlrd
wb = xlrd.open_workbook("01-EmployeeData.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []

for j in range (0, ws.nrows):
    for i in range (0, ws.ncols):
        if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
            myList1.append("NO VALID DATA")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
print (myList2)
print (len(myList2))
# Out:
# [['SLNO', 'serial', 'Emp Name', 'Email ID', 'Final Grade', 'Location', 'Fresher', 'Hire Date', 'LWD', 'Practice', 'Service Line', 'Primary Skills', 'Secondary Skill', 'Supervisor Name', 'PID', 'Project Name', 'Project Manager', 'Account', 'Allocation Start Date', 'Allocation end date', 'Allocation Start Date2', 'Allocation end Date2', 'Start month', 'End month', 'Net working days', 'Copy of U', 'Vlook up formual', 'Consideration of start and end dates', 'Copy of X', 'Division', 'Consideration of Abscondee, Long Leave p/up', 'FTE', 'Resource Current Status ', 'Delivery BU', 'Delivery Region', 'Sector/Country', 'OU Code', 'SEZ/Non-SEZ', 'Emp Type', 'Captives/P&C', 'Generic Skill', 'Project Type', 'Resource Type', 'Hire month'], ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA'], ['ID0002', 165439.0, 'Abhinava Abhinava', 'emp_name@mail.com2', 'B', 'Bangalore', 'No', 43404.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Prachi Vinay Kulkarni', 'PID0002', 'PN002', 'PM002', 'AC002', 43864.333333333336, 44008.708333333336, 43864.0, 44008.0, 43983.0, 44008.0, 20.0, 20.0, 20.0, 22.0, 22.0, 0.9090909090909091, 0.9090909090909091, 0.9090909090909091, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0003', 175212.0, 'abhishek kumar', 'emp_name@mail.com3', 'B', 'Bangalore', 'No', 43521.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0003', 'PN003', 'PM003', 'AC003', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.5789473684210527, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0004', 159885.0, 'Abhishek Shukla', 'emp_name@mail.com4', 'A', 'Bangalore', 'Yes', 43348.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Rajendran Manickam', 'PID0004', 'PN004', 'PM004', 'AC004', 43830.333333333336, 44196.708333333336, 43830.0, 44196.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Billable', 'DCX', 'INDIA', 'IN', 'IN52', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0005', 116244.0, 'Adarsh Valamary', 'emp_name@mail.com5', 'B', 'Bangalore', 'No', 42644.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Govind Murari', 'PID0005', 'PN005', 'PM005', 'AC005', 43864.333333333336, 44001.708333333336, 43864.0, 44001.0, 43983.0, 44001.0, 15.0, 15.0, 17.0, 22.0, 22.0, 0.6818181818181818, 0.6818181818181818, 0.6818181818181818, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'Non-SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0006', 46000800.0, 'Aditi Pal', 'emp_name@mail.com6', 'A', 'Mumbai', 'Yes', 43690.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'NO VALID DATA', 'Noshir Aspi Patel', 'PID0006', 'PN006', 'PM006', 'AC006', 43920.333333333336, 44012.708333333336, 43920.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Shadow', 'DCX', 'INDIA', 'IN', 'IN45', 'Non-SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA'], ['ID0007', 75029.0, 'Aditi Sharma', 'emp_name@mail.com7', 'C', 'Bangalore', 'No', 42086.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0007', 'PN007', 'PM007', 'AC007', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.578947 ...
# 291

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 03
# Observation: Time taken to fetch the file (Workbook) and navigate to the Worksheet is very high.
# Execution of for loop hardly takes any time. 

import xlrd
import time
startTime = time.time()
wb = xlrd.open_workbook("01-EmployeeData.xlsx")
ws = wb.sheet_by_index(0)
myList1 = []
myList2 = []
# startTime = time.time()
for j in range (0, ws.nrows):
    for i in range (0, ws.ncols):
        if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
            myList1.append("NO VALID DATA")
        else:
            myList1.append(ws.cell_value(j, i))
    myList2.append(myList1)
    myList1 = []
print (myList2)
endTime = time.time()
print ("Total time in seconds to execute this code:", (endTime - startTime))
# Out:
# [['SLNO', 'serial', 'Emp Name', 'Email ID', 'Final Grade', 'Location', 'Fresher', 'Hire Date', 'LWD', 'Practice', 'Service Line', 'Primary Skills', 'Secondary Skill', 'Supervisor Name', 'PID', 'Project Name', 'Project Manager', 'Account', 'Allocation Start Date', 'Allocation end date', 'Allocation Start Date2', 'Allocation end Date2', 'Start month', 'End month', 'Net working days', 'Copy of U', 'Vlook up formual', 'Consideration of start and end dates', 'Copy of X', 'Division', 'Consideration of Abscondee, Long Leave p/up', 'FTE', 'Resource Current Status ', 'Delivery BU', 'Delivery Region', 'Sector/Country', 'OU Code', 'SEZ/Non-SEZ', 'Emp Type', 'Captives/P&C', 'Generic Skill', 'Project Type', 'Resource Type', 'Hire month'], ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', '', 'No', '', 'CSS', ''], ['ID0002', 165439.0, 'Abhinava Abhinava', 'emp_name@mail.com2', 'B', 'Bangalore', 'No', 43404.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Prachi Vinay Kulkarni', 'PID0002', 'PN002', 'PM002', 'AC002', 43864.333333333336, 44008.708333333336, 43864.0, 44008.0, 43983.0, 44008.0, 20.0, 20.0, 20.0, 22.0, 22.0, 0.9090909090909091, 0.9090909090909091, 0.9090909090909091, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0003', 175212.0, 'abhishek kumar', 'emp_name@mail.com3', 'B', 'Bangalore', 'No', 43521.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0003', 'PN003', 'PM003', 'AC003', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.5789473684210527, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0004', 159885.0, 'Abhishek Shukla', 'emp_name@mail.com4', 'A', 'Bangalore', 'Yes', 43348.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Rajendran Manickam', 'PID0004', 'PN004', 'PM004', 'AC004', 43830.333333333336, 44196.708333333336, 43830.0, 44196.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Billable', 'DCX', 'INDIA', 'IN', 'IN52', 'SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0005', 116244.0, 'Adarsh Valamary', 'emp_name@mail.com5', 'B', 'Bangalore', 'No', 42644.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Govind Murari', 'PID0005', 'PN005', 'PM005', 'AC005', 43864.333333333336, 44001.708333333336, 43864.0, 44001.0, 43983.0, 44001.0, 15.0, 15.0, 17.0, 22.0, 22.0, 0.6818181818181818, 0.6818181818181818, 0.6818181818181818, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'Non-SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0006', 46000800.0, 'Aditi Pal', 'emp_name@mail.com6', 'A', 'Mumbai', 'Yes', 43690.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', '', 'Noshir Aspi Patel', 'PID0006', 'PN006', 'PM006', 'AC006', 43920.333333333336, 44012.708333333336, 43920.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Shadow', 'DCX', 'INDIA', 'IN', 'IN45', 'Non-SEZ', 'Standard', '', 'No', '', 'CSS', ''], ['ID0007', 75029.0, 'Aditi Sharma', 'emp_name@mail.com7', 'C', 'Bangalore', 'No', 42086.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0007', 'PN007', 'PM007', 'AC007', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.5789473684210527, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'Non-SEZ', 'Standard', '', 'No', 'External', 'CSS', ''], ['ID0008', 114099.0, 'Aditya Kumar', 'emp_name@mail.com8', 'C', 'Bangalore', 'No', 42644.0, '--', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Mathew Easow Ja ...
# Total time in seconds to execute this code: 12.822669982910156

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 04
# Exception handling included.

import xlrd
import time
try:
    startTime = time.time()
    wb = xlrd.open_workbook("01-EmployeeData-Sample.xlsx")
    ws = wb.sheet_by_index(0)
    myList1 = []
    myList2 = []
    # startTime = time.time()
    for j in range (0, ws.nrows):
        for i in range (0, ws.ncols):
            if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
                myList1.append("NO VALID DATA")
            else:
                myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    print (myList2)
    endTime = time.time()
    print ("Total time in seconds to execute this code:", (endTime - startTime))
except FileNotFoundError:
    print ("Error: FILE NOT FOUND")
# Out:
# [['SLNO', 'serial', 'Emp Name', 'Email ID', 'Final Grade', 'Location', 'Fresher', 'Hire Date', 'LWD', 'Practice', 'Service Line', 'Primary Skills', 'Secondary Skill', 'Supervisor Name', 'PID', 'Project Name', 'Project Manager', 'Account', 'Allocation Start Date', 'Allocation end date', 'Allocation Start Date2', 'Allocation end Date2', 'Start month', 'End month', 'Net working days', 'Copy of U', 'Vlook up formual', 'Consideration of start and end dates', 'Copy of X', 'Division', 'Consideration of Abscondee, Long Leave p/up', 'FTE', 'Resource Current Status ', 'Delivery BU', 'Delivery Region', 'Sector/Country', 'OU Code', 'SEZ/Non-SEZ', 'Emp Type', 'Captives/P&C', 'Generic Skill', 'Project Type', 'Resource Type', 'Hire month'], ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA'], ['ID0002', 165439.0, 'Abhinava Abhinava', 'emp_name@mail.com2', 'B', 'Bangalore', 'No', 43404.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Prachi Vinay Kulkarni', 'PID0002', 'PN002', 'PM002', 'AC002', 43864.333333333336, 44008.708333333336, 43864.0, 44008.0, 43983.0, 44008.0, 20.0, 20.0, 20.0, 22.0, 22.0, 0.9090909090909091, 0.9090909090909091, 0.9090909090909091, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0003', 175212.0, 'abhishek kumar', 'emp_name@mail.com3', 'B', 'Bangalore', 'No', 43521.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0003', 'PN003', 'PM003', 'AC003', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.5789473684210527, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0004', 159885.0, 'Abhishek Shukla', 'emp_name@mail.com4', 'A', 'Bangalore', 'Yes', 43348.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Rajendran Manickam', 'PID0004', 'PN004', 'PM004', 'AC004', 43830.333333333336, 44196.708333333336, 43830.0, 44196.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Billable', 'DCX', 'INDIA', 'IN', 'IN52', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0005', 116244.0, 'Adarsh Valamary', 'emp_name@mail.com5', 'B', 'Bangalore', 'No', 42644.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Govind Murari', 'PID0005', 'PN005', 'PM005', 'AC005', 43864.333333333336, 44001.708333333336, 43864.0, 44001.0, 43983.0, 44001.0, 15.0, 15.0, 17.0, 22.0, 22.0, 0.6818181818181818, 0.6818181818181818, 0.6818181818181818, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'Non-SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0006', 46000800.0, 'Aditi Pal', 'emp_name@mail.com6', 'A', 'Mumbai', 'Yes', 43690.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'NO VALID DATA', 'Noshir Aspi Patel', 'PID0006', 'PN006', 'PM006', 'AC006', 43920.333333333336, 44012.708333333336, 43920.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Shadow', 'DCX', 'INDIA', 'IN', 'IN45', 'Non-SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA'], ['ID0007', 75029.0, 'Aditi Sharma', 'emp_name@mail.com7', 'C', 'Bangalore', 'No', 42086.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0007', 'PN007', 'PM007', 'AC007', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.578947 ...
# Total time in seconds to execute this code: 0.05096936225891113
# 116244.0

# %%
# Search employee ID

# print (myList2[0][0])
for i in range (0, ws.nrows):
    for j in range (0, ws.ncols):
        # print (myList2[i][j])
        if myList2[i][j] == 116244:
            print ("This is just getting wonderful", i, j)
        else:
            print ("String Found")
print (myList2[5][1])
print ("\n")
for i in range (0, 43):
    print (ws.cell_value(5, i))
# Out:
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# This is just getting wonderful 5 1
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# String Found
# 116244.0
#
#
# ID0005
# 116244.0
# Adarsh Valamary
# emp_name@mail.com5
# B
# Bangalore
# No
# 42644.0
# --
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Govind Murari
# PID0005
# PN005
# PM005
# AC005
# 43864.333333333336
# 44001.708333333336
# 43864.0
# 44001.0
# 43983.0
# 44001.0
# 15.0
# 15.0
# 17.0
# 22.0
# 22.0
# 0.6818181818181818
# 0.6818181818181818
# 0.6818181818181818
# Billable
# DCX
# INDIA
# IN
# IN71
# Non-SEZ
# Standard
#
# No
# External
# CSS

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 05

import xlrd
import time
try:
    startTime = time.time()
    wb = xlrd.open_workbook("01-EmployeeData-Sample.xlsx")
    ws = wb.sheet_by_index(0)
    myList1 = []
    myList2 = []
    # startTime = time.time()
    for j in range (0, ws.nrows):
        for i in range (0, ws.ncols):
            if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
                myList1.append("NO VALID DATA")
            else:
                myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    # print (myList2)
    endTime = time.time()
    print ("Total time in seconds to execute this code:", (endTime - startTime))
    
    # Search employee ID
    myList3 = []
    mySet = set()
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            if myList2[i][j] == 123456:
                # print ("This is just getting wonderful", i, j)
                varImp = i
                # print (varImp)
            else:
                mySet.add ('String Not Found')
                # print ("String Found")
    for i in range (0, 43):
        myList3.append(ws.cell_value(varImp, i))
    print (myList3)
    print (mySet)
except FileNotFoundError:
    print ("Error: FILE NOT FOUND")
# Out:
# Total time in seconds to execute this code: 0.06896090507507324
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57774cb37280> in <module>
#      35                 # print ("String Found")
#      36     for i in range (0, 43):
# ---> 37         myList3.append(ws.cell_value(varImp, i))
#      38
#      39 #
#
# NameError: name 'varImp' is not defined

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 06

import xlrd
# import time

try:
    # startTime = time.time()
    wb = xlrd.open_workbook("01-EmployeeData-Sample.xlsx")
    ws = wb.sheet_by_index(0)
    myList1 = []
    myList2 = []
    # startTime = time.time()
    for j in range (0, ws.nrows):
        for i in range (0, ws.ncols):
            if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
                myList1.append("NO VALID DATA")
            else:
                myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    print (myList2)
    # endTime = time.time()
    # print ("Total time in seconds to execute this code:", (endTime - startTime))
    
    # Search employee ID
    myList3 = []
    mySet = set()
    varImp = 0
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            if myList2[i][j] == 165439.0:
                # print ("This is just getting wonderful", i, j)
                varImp = i
                # print (varImp)
                for i in range (0, 43):
                    myList3.append(ws.cell_value(varImp, i))
            else:
                mySet.add ('String Not Found')
                # print ("String Found")
    
    if myList3 != []:
        print (myList3)
    else:
        print (mySet)
except FileNotFoundError:
    print ("Error: FILE NOT FOUND")
# Out:
# [['SLNO', 'serial', 'Emp Name', 'Email ID', 'Final Grade', 'Location', 'Fresher', 'Hire Date', 'LWD', 'Practice', 'Service Line', 'Primary Skills', 'Secondary Skill', 'Supervisor Name', 'PID', 'Project Name', 'Project Manager', 'Account', 'Allocation Start Date', 'Allocation end date', 'Allocation Start Date2', 'Allocation end Date2', 'Start month', 'End month', 'Net working days', 'Copy of U', 'Vlook up formual', 'Consideration of start and end dates', 'Copy of X', 'Division', 'Consideration of Abscondee, Long Leave p/up', 'FTE', 'Resource Current Status ', 'Delivery BU', 'Delivery Region', 'Sector/Country', 'OU Code', 'SEZ/Non-SEZ', 'Emp Type', 'Captives/P&C', 'Generic Skill', 'Project Type', 'Resource Type', 'Hire month'], ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA'], ['ID0002', 165439.0, 'Abhinava Abhinava', 'emp_name@mail.com2', 'B', 'Bangalore', 'No', 43404.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Prachi Vinay Kulkarni', 'PID0002', 'PN002', 'PM002', 'AC002', 43864.333333333336, 44008.708333333336, 43864.0, 44008.0, 43983.0, 44008.0, 20.0, 20.0, 20.0, 22.0, 22.0, 0.9090909090909091, 0.9090909090909091, 0.9090909090909091, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0003', 175212.0, 'abhishek kumar', 'emp_name@mail.com3', 'B', 'Bangalore', 'No', 43521.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0003', 'PN003', 'PM003', 'AC003', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.5789473684210527, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0004', 159885.0, 'Abhishek Shukla', 'emp_name@mail.com4', 'A', 'Bangalore', 'Yes', 43348.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Rajendran Manickam', 'PID0004', 'PN004', 'PM004', 'AC004', 43830.333333333336, 44196.708333333336, 43830.0, 44196.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Billable', 'DCX', 'INDIA', 'IN', 'IN52', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0005', 116244.0, 'Adarsh Valamary', 'emp_name@mail.com5', 'B', 'Bangalore', 'No', 42644.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Govind Murari', 'PID0005', 'PN005', 'PM005', 'AC005', 43864.333333333336, 44001.708333333336, 43864.0, 44001.0, 43983.0, 44001.0, 15.0, 15.0, 17.0, 22.0, 22.0, 0.6818181818181818, 0.6818181818181818, 0.6818181818181818, 'Billable', 'DCX', 'INDIA', 'IN', 'IN71', 'Non-SEZ', 'Standard', 'NO VALID DATA', 'No', 'External', 'CSS', 'NO VALID DATA'], ['ID0006', 46000800.0, 'Aditi Pal', 'emp_name@mail.com6', 'A', 'Mumbai', 'Yes', 43690.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'NO VALID DATA', 'Noshir Aspi Patel', 'PID0006', 'PN006', 'PM006', 'AC006', 43920.333333333336, 44012.708333333336, 43920.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Shadow', 'DCX', 'INDIA', 'IN', 'IN45', 'Non-SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA'], ['ID0007', 75029.0, 'Aditi Sharma', 'emp_name@mail.com7', 'C', 'Bangalore', 'No', 42086.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Ramakrishna Cherukuri', 'PID0007', 'PN007', 'PM007', 'AC007', 43801.333333333336, 44043.708333333336, 43801.0, 44043.0, 43983.0, 44012.0, 22.0, 22.0, 38.0, 38.0, 38.0, 0.5789473684210527, 0.5789473684210527, 0.578947 ...
# Total time in seconds to execute this code: 0.0359807014465332
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-c40dd2a8ace3> in <module>
#      29     for i in range (0, ws.nrows):
#      30         for j in range (0, ws.ncols):
# ---> 31             if myList2[i][j] == 165439.0:
#      32                 # print ("This is just getting wonderful", i, j)
#      33                 varImp = i
#
# IndexError: list index out of range

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 07

import xlrd

try:
    wb = xlrd.open_workbook("01-EmployeeData-Sample.xlsx")
    ws = wb.sheet_by_index(0)
    myList1 = []
    myList2 = []
    for j in range (0, ws.nrows):
        for i in range (0, ws.ncols):
            if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
                myList1.append("NO VALID DATA")
            else:
                myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    # print (myList2)
    
    # Search employee ID
    myList3 = []
    mySet = set()
    varImp = 0
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            print (myList2[i][j])
            if myList2[i][j] == 159492.0:
                print ("**************Success**************", i, myList2[i])
                
#                varImp = i
#                for i in range (0, ws.ncols):
#                    myList3.append(ws.cell_value(varImp, i))
#            else:
#                mySet.add ('String Not Found')
    
#    if myList3 != []:
#        print (myList3)
#    else:
#        print (mySet)
except FileNotFoundError:
    print ("Error: FILE NOT FOUND")
# Out:
# SLNO
# serial
# Emp Name
# Email ID
# Final Grade
# Location
# Fresher
# Hire Date
# LWD
# Practice
# Service Line
# Primary Skills
# Secondary Skill
# Supervisor Name
# PID
# Project Name
# Project Manager
# Account
# Allocation Start Date
# Allocation end date
# Allocation Start Date2
# Allocation end Date2
# Start month
# End month
# Net working days
# Copy of U
# Vlook up formual
# Consideration of start and end dates
# Copy of X
# Division
# Consideration of Abscondee, Long Leave p/up
# FTE
# Resource Current Status
# Delivery BU
# Delivery Region
# Sector/Country
# OU Code
# SEZ/Non-SEZ
# Emp Type
# Captives/P&C
# Generic Skill
# Project Type
# Resource Type
# Hire month
# ID0001
# 159492.0
# **************Success************** 1 ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA']
# Aarohi Mondkar
# emp_name@mail.com1
# B
# Mumbai
# No
# 43346.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Noshir Aspi Patel
# PID0001
# PN001
# PM001
# AC001
# 43966.0
# 44012.0
# 43966.0
# 44012.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Bench
# DCX
# INDIA
# IN
# INA8
# SEZ
# Standard
# NO VALID DATA
# No
# NO VALID DATA
# CSS
# NO VALID DATA
# ID0002
# 165439.0
# Abhinava Abhinava
# emp_name@mail.com2
# B
# Bangalore
# No
# 43404.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Prachi Vinay Kulkarni
# PID0002
# PN002
# PM002
# AC002
# 43864.333333333336
# 44008.708333333336
# 43864.0
# 44008.0
# 43983.0
# 44008.0
# 20.0
# 20.0
# 20.0
# 22.0
# 22.0
# 0.9090909090909091
# 0.9090909090909091
# 0.9090909090909091
# Billable
# DCX
# INDIA
# IN
# IN71
# SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0003
# 175212.0
# abhishek kumar
# emp_name@mail.com3
# B
# Bangalore
# No
# 43521.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Ramakrishna Cherukuri
# PID0003
# PN003
# PM003
# AC003
# 43801.333333333336
# 44043.708333333336
# 43801.0
# 44043.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 38.0
# 38.0
# 38.0
# 0.5789473684210527
# 0.5789473684210527
# 0.5789473684210527
# Billable
# DCX
# INDIA
# IN
# IN71
# SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0004
# 159885.0
# Abhishek Shukla
# emp_name@mail.com4
# A
# Bangalore
# Yes
# 43348.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Rajendran Manickam
# PID0004
# PN004
# PM004
# AC004
# 43830.333333333336
# 44196.708333333336
# 43830.0
# 44196.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Billable
# DCX
# INDIA
# IN
# IN52
# SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0005
# 116244.0
# Adarsh Valamary
# emp_name@mail.com5
# B
# Bangalore
# No
# 42644.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Govind Murari
# PID0005
# PN005
# PM005
# AC005
# 43864.333333333336
# 44001.708333333336
# 43864.0
# 44001.0
# 43983.0
# 44001.0
# 15.0
# 15.0
# 17.0
# 22.0
# 22.0
# 0.6818181818181818
# 0.6818181818181818
# 0.6818181818181818
# Billable
# DCX
# INDIA
# IN
# IN71
# Non-SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0006
# 46000800.0
# Aditi Pal
# emp_name@mail.com6
# A
# Mumbai
# Yes
# 43690.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# NO VALID DATA
# Noshir Aspi Patel
# PID0006
# PN006
# PM006
# AC006
# 43920.333333333336
# 44012.708333333336
# 43920.0
# 44012.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Shadow
# DCX
# INDIA
# IN
# IN45
# Non-SEZ
# Standard
# NO VALID DATA
# No
# NO VALID DATA
# CSS
# NO VALID DATA
# ID0007
# 75029.0
# Aditi Sharma
# emp_name@mail.com7
# C
# Bangalore
# No
# 42086.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Ramakrishna Cherukuri
# PID0007
# PN007
# PM007
# AC007
# 43801.333333333336
# 44043.708333333336
# 43801.0
# 44043.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 38.0
# 38.0
# 38.0
# 0.5789473684210527
# 0.5789473684210527
# 0.5789473684210527
# Billable
# DCX
# INDIA
# IN
# IN71
# Non-SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0008
# 114099.0
# Aditya Kumar
# emp_name@mail.com8
# C
# Bangalore
# No
# 42644.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Mathew Easow Jacob
# PID0008
# PN008
# PM008
# AC008
# 43773.333333333336
# 44104.708333333336
# 43773.0
# 44104.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Billable
# DCX
# INDIA
# IN
# IN52
# SEZ
# Standard
# NO VALID DATA
# No
# Internal
# CSS
# NO VALID DATA
# ID0009
# 103563.0
# Ajit Kumar Giri
# emp_name@mail.com9
# C
# Bangalore
# No
# 42726.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Nikhil Raj
# PID0009
# PN009
# PM009
# AC009
# 43922.333333333336
# 44196.708333333336
# 43922.0
# 44196.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Billable
# DCX
# INDIA
# IN
# IN19
# Non-SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 07

import xlrd

try:
    wb = xlrd.open_workbook("01-EmployeeData-Sample.xlsx")
    ws = wb.sheet_by_index(0)
    myList1 = []
    myList2 = []
    for j in range (0, ws.nrows):
        for i in range (0, ws.ncols):
            if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
                myList1.append("NO VALID DATA")
            else:
                myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    # print (myList2)
    
    # Search employee ID
    myList3 = []
    mySet = set()
    varImp = 0
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            # print (myList2[i][j])
            if myList2[i][j] == 159492.0:
                # print ("**************Success**************", i, myList2[i])
                myList3.append(myList2[i])
    print (myList3)
except FileNotFoundError:
    print ("Error: FILE NOT FOUND")
# Out:
# SLNO
# serial
# Emp Name
# Email ID
# Final Grade
# Location
# Fresher
# Hire Date
# LWD
# Practice
# Service Line
# Primary Skills
# Secondary Skill
# Supervisor Name
# PID
# Project Name
# Project Manager
# Account
# Allocation Start Date
# Allocation end date
# Allocation Start Date2
# Allocation end Date2
# Start month
# End month
# Net working days
# Copy of U
# Vlook up formual
# Consideration of start and end dates
# Copy of X
# Division
# Consideration of Abscondee, Long Leave p/up
# FTE
# Resource Current Status
# Delivery BU
# Delivery Region
# Sector/Country
# OU Code
# SEZ/Non-SEZ
# Emp Type
# Captives/P&C
# Generic Skill
# Project Type
# Resource Type
# Hire month
# ID0001
# 159492.0
# **************Success************** 1 ['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA']
# Aarohi Mondkar
# emp_name@mail.com1
# B
# Mumbai
# No
# 43346.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Noshir Aspi Patel
# PID0001
# PN001
# PM001
# AC001
# 43966.0
# 44012.0
# 43966.0
# 44012.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Bench
# DCX
# INDIA
# IN
# INA8
# SEZ
# Standard
# NO VALID DATA
# No
# NO VALID DATA
# CSS
# NO VALID DATA
# ID0002
# 165439.0
# Abhinava Abhinava
# emp_name@mail.com2
# B
# Bangalore
# No
# 43404.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Prachi Vinay Kulkarni
# PID0002
# PN002
# PM002
# AC002
# 43864.333333333336
# 44008.708333333336
# 43864.0
# 44008.0
# 43983.0
# 44008.0
# 20.0
# 20.0
# 20.0
# 22.0
# 22.0
# 0.9090909090909091
# 0.9090909090909091
# 0.9090909090909091
# Billable
# DCX
# INDIA
# IN
# IN71
# SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0003
# 175212.0
# abhishek kumar
# emp_name@mail.com3
# B
# Bangalore
# No
# 43521.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Ramakrishna Cherukuri
# PID0003
# PN003
# PM003
# AC003
# 43801.333333333336
# 44043.708333333336
# 43801.0
# 44043.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 38.0
# 38.0
# 38.0
# 0.5789473684210527
# 0.5789473684210527
# 0.5789473684210527
# Billable
# DCX
# INDIA
# IN
# IN71
# SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0004
# 159885.0
# Abhishek Shukla
# emp_name@mail.com4
# A
# Bangalore
# Yes
# 43348.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Rajendran Manickam
# PID0004
# PN004
# PM004
# AC004
# 43830.333333333336
# 44196.708333333336
# 43830.0
# 44196.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Billable
# DCX
# INDIA
# IN
# IN52
# SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0005
# 116244.0
# Adarsh Valamary
# emp_name@mail.com5
# B
# Bangalore
# No
# 42644.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Govind Murari
# PID0005
# PN005
# PM005
# AC005
# 43864.333333333336
# 44001.708333333336
# 43864.0
# 44001.0
# 43983.0
# 44001.0
# 15.0
# 15.0
# 17.0
# 22.0
# 22.0
# 0.6818181818181818
# 0.6818181818181818
# 0.6818181818181818
# Billable
# DCX
# INDIA
# IN
# IN71
# Non-SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0006
# 46000800.0
# Aditi Pal
# emp_name@mail.com6
# A
# Mumbai
# Yes
# 43690.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# NO VALID DATA
# Noshir Aspi Patel
# PID0006
# PN006
# PM006
# AC006
# 43920.333333333336
# 44012.708333333336
# 43920.0
# 44012.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Shadow
# DCX
# INDIA
# IN
# IN45
# Non-SEZ
# Standard
# NO VALID DATA
# No
# NO VALID DATA
# CSS
# NO VALID DATA
# ID0007
# 75029.0
# Aditi Sharma
# emp_name@mail.com7
# C
# Bangalore
# No
# 42086.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Ramakrishna Cherukuri
# PID0007
# PN007
# PM007
# AC007
# 43801.333333333336
# 44043.708333333336
# 43801.0
# 44043.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 38.0
# 38.0
# 38.0
# 0.5789473684210527
# 0.5789473684210527
# 0.5789473684210527
# Billable
# DCX
# INDIA
# IN
# IN71
# Non-SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# ID0008
# 114099.0
# Aditya Kumar
# emp_name@mail.com8
# C
# Bangalore
# No
# 42644.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Mathew Easow Jacob
# PID0008
# PN008
# PM008
# AC008
# 43773.333333333336
# 44104.708333333336
# 43773.0
# 44104.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Billable
# DCX
# INDIA
# IN
# IN52
# SEZ
# Standard
# NO VALID DATA
# No
# Internal
# CSS
# NO VALID DATA
# ID0009
# 103563.0
# Ajit Kumar Giri
# emp_name@mail.com9
# C
# Bangalore
# No
# 42726.0
# NO VALID DATA
# Front end UX/UI
# WEBUI
# Angular
# MEAN
# Nikhil Raj
# PID0009
# PN009
# PM009
# AC009
# 43922.333333333336
# 44196.708333333336
# 43922.0
# 44196.0
# 43983.0
# 44012.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 1.0
# 1.0
# 1.0
# Billable
# DCX
# INDIA
# IN
# IN19
# Non-SEZ
# Standard
# NO VALID DATA
# No
# External
# CSS
# NO VALID DATA
# [['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA']]

# %%
# Code to extract employee data from MS Excel sheet using XLRD package - Iteration 07

import xlrd

try:
    wb = xlrd.open_workbook("01-EmployeeData-Sample.xlsx")
    ws = wb.sheet_by_index(0)
    myList1 = []
    myList2 = []
    for j in range (0, ws.nrows):
        for i in range (0, ws.ncols):
            if ws.cell_value(j, i) == '' or ws.cell_value(j, i) == '--':
                myList1.append("NO VALID DATA")
            else:
                myList1.append(ws.cell_value(j, i))
        myList2.append(myList1)
        myList1 = []
    
    # Code to Search employee ID
    myList3 = []
    mySet = set()
    varImp = 0
    for i in range (0, ws.nrows):
        for j in range (0, ws.ncols):
            if myList2[i][j] == 159492.0:
                myList3.append(myList2[i])

    if (myList3):
        print (myList3)
    else:
        print ("Employee ID Not found")
except FileNotFoundError:
    print ("Error: FILE NOT FOUND")
# Out:
# [['ID0001', 159492.0, 'Aarohi Mondkar', 'emp_name@mail.com1', 'B', 'Mumbai', 'No', 43346.0, 'NO VALID DATA', 'Front end UX/UI', 'WEBUI', 'Angular', 'MEAN', 'Noshir Aspi Patel', 'PID0001', 'PN001', 'PM001', 'AC001', 43966.0, 44012.0, 43966.0, 44012.0, 43983.0, 44012.0, 22.0, 22.0, 22.0, 22.0, 22.0, 1.0, 1.0, 1.0, 'Bench', 'DCX', 'INDIA', 'IN', 'INA8', 'SEZ', 'Standard', 'NO VALID DATA', 'No', 'NO VALID DATA', 'CSS', 'NO VALID DATA']]

# %%
del myList1
del myList2
del myList3
del mySet
del varImp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c466f897d244> in <module>
#       3 del myList3
#       4 del mySet
# ----> 5 del varImp
#
# NameError: name 'varImp' is not defined
