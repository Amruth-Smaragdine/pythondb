# %%
from ipywidgets import (widgets, interact, interactive, interact_manual, fixed)
from IPython.display import clear_output
import numpy as np
logging.basicConfig(level=logging.ERROR, format='%(lineno)s %(levelname)s %(message)s')
logger = logging.getlogger()
logger.setLevel(logging.CRITICAL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c4f76611f6ca> in <module>
#       2 from IPython.display import clear_output
#       3 import numpy as np
# ----> 4 logging.basicConfig(level=logging.ERROR, format='%(lineno)s %(levelname)s %(message)s')
#       5 logger = logging.getlogger()
#       6 logger.setLevel(logging.CRITICAL)
#
# NameError: name 'logging' is not defined

# %%
import sys
# !{sys.executable} -m pip list | findstr "indic_transliteration"
# !{sys.executable} -m pip list > packages.csv

# %%
print (locals().values())
# Out:
# dict_values(['__main__', 'Automatically created module for IPython interactive environment', None, None, None, <module 'builtins' (built-in)>, <module 'builtins' (built-in)>, ['', "from ipywidgets import (widgets, interact, interactive, interact_manual, fixed)\nfrom IPython.display import clear_output\nimport numpy as np\nloggging.basicConfig(\n    level=logging.ERROR, format='%(lineno)s %(levelname)s %(message)s')\nlogger = logging.getlogger()\nlogger.setLevel(logging.CRITICAL)", "from ipywidgets import (widgets, interact, interactive, interact_manual, fixed)\nfrom IPython.display import clear_output\nimport numpy as np\nlogging.basicConfig(\n    level=logging.ERROR, format='%(lineno)s %(levelname)s %(message)s')\nlogger = logging.getlogger()\nlogger.setLevel(logging.CRITICAL)", "from ipywidgets import (widgets, interact, interactive, interact_manual, fixed)\nfrom IPython.display import clear_output\nimport numpy as np\nlogging.basicConfig(level=logging.ERROR, format='%(lineno)s %(l
# ...
